# %% [markdown]
# <a href="https://colab.research.google.com/github/Nido89/LinearregressionwithML/blob/master/AIMLProject1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python

try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen

import json


def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    response = urlopen(url)
    data = response.read().decode("utf-8")
    return json.loads(data)


url = ("https://meri.digitraffic.fi/api/v1/metadata/vessels")
print(get_jsonparsed_data(url))
# Out:
# [{'timestamp': 1566342468463, 'destination': '', 'name': 'HMS TROSSO', 'mmsi': 265837000, 'callSign': 'SGFQ', 'imo': 8119027, 'shipType': 35, 'draught': 50, 'eta': 1596, 'posType': 1, 'referencePointA': 19, 'referencePointB': 51, 'referencePointC': 6, 'referencePointD': 6}, {'timestamp': 1566969500325, 'destination': 'ROOMASSAARE  ABRUKA', 'name': 'ABRO', 'mmsi': 276808000, 'callSign': 'ESKA', 'imo': 0, 'shipType': 60, 'draught': 0, 'eta': 1596, 'posType': 1, 'referencePointA': 5, 'referencePointB': 10, 'referencePointC': 2, 'referencePointD': 2}, {'timestamp': 1539814227596, 'destination': 'SPB', 'name': 'VOLGONEFT-102', 'mmsi': 273274000, 'callSign': 'UBCE', 'imo': 0, 'shipType': 90, 'draught': 36, 'eta': 691456, 'posType': 15, 'referencePointA': 103, 'referencePointB': 23, 'referencePointC': 6, 'referencePointD': 10}, {'timestamp': 1570529851474, 'destination': 'EETLL-BEANR', 'name': 'MSC UMA', 'mmsi': 255806082, 'callSign': 'CQIV8', 'imo': 9163192, 'shipType': 70, 'draught': 107,
# ...

# %%
import pandas as pd
df = pd.read_json("https://meri.digitraffic.fi/api/v1/metadata/vessels")
df.head()
# Out:
#   callSign          destination  ...  shipType               timestamp
# 0     SGFQ                       ...        35 2019-08-20 23:07:48.463
# 1     ESKA  ROOMASSAARE  ABRUKA  ...        60 2019-08-28 05:18:20.325
# 2     UBCE                  SPB  ...        90 2018-10-17 22:10:27.596
# 3    CQIV8          EETLL-BEANR  ...        70 2019-10-08 10:17:31.474
# 4    UBMJ4                  SPB  ...        80 2019-09-27 23:51:08.734
#
# [5 rows x 14 columns]

# %%
c = pd.read_csv("https://cdn.fmi.fi/fmiodata-convert-api/output/csv-437ad883-133e-4a3d-b79e-8027d2ac3b45.csv")

print(c)
# Out:
#     Year   m   d   Time Time zone  Horizontal visibility (m)  Wind speed (m/s)
# 0   2019  10  11  00:00       UTC                      50000               2.4
# 1   2019  10  11  01:00       UTC                      28420               1.9
# 2   2019  10  11  02:00       UTC                      32740               1.6
# 3   2019  10  11  03:00       UTC                      17540               2.2
# 4   2019  10  11  04:00       UTC                       5670               2.1
# 5   2019  10  11  05:00       UTC                      36930               2.2
# 6   2019  10  11  06:00       UTC                      50000               2.1
# 7   2019  10  11  07:00       UTC                      42190               2.7
# 8   2019  10  11  08:00       UTC                      42480               3.7
# 9   2019  10  11  09:00       UTC                      50000               3.8
# 10  2019  10  11  10:00       UTC                      43710               3.9
# ...

# %%
import pandas as pd
url='https://cdn.fmi.fi/fmiodata-convert-api/output/csv-437ad883-133e-4a3d-b79e-8027d2ac3b45.csv'
df1 = pd.read_csv(url) 
df1.head(4)
# Out:
#    Year   m   d   Time Time zone  Horizontal visibility (m)  Wind speed (m/s)
# 0  2019  10  11  00:00       UTC                      50000               2.4
# 1  2019  10  11  01:00       UTC                      28420               1.9
# 2  2019  10  11  02:00       UTC                      32740               1.6
# 3  2019  10  11  03:00       UTC                      17540               2.2
